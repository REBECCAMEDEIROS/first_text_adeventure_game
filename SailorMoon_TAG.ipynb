# %%
#Author: Rebecca Medeiros
#Description: Adventure Text Game Sailor Moon


#Display Introduction 
"""
DocString:

The Dark Kingdom, ruled by Queen Beryl, will stop at nothing to feed their
     master overlord, Queen Meteria, with human souls harvested by evil 
      Youma Monsters. These evil entities also search for the powerful 
              Silver Crystal, which is somewhere in Tokyo.
      The Sailor Scouts are reincarnate Warrior Guardians of the 
                 Silver Millennium Moon Kingdom. 
        They are tasked with finding the Moon Princess, 
                           Serenity, 
                 to battle the Dark Kingdom, 
            as she is the one with the Silver Crystal. 
                       The power of the
                       Silver Crystal 
               will restore and protect the world.

            The goal for the player is to trust Luna, 
          harness their Sailor Scout powers, join the rest
        of the Scout Guardians, locate the princess,and battle 
              the monsters and the Dark Kingdom leaders.

           The player will go through 5 stages without giving up or dying!

                  Stage 1: Receive your Pendant from Luna
             Stage 2: Follow Luna to find your Sailor Guardian Power
                Stage 3: Find the other Sailor Scouts
            Stage 4: Find Princess Serenity and the Silver Crystal 
                   Stage 5: Battle the Dark Kingdom
                   
Sailor Moon Sources


https://en.wikipedia.org/wiki/Sailor_Moon

https://www.imdb.com/title/tt0114327/

Resources Used
https://stackoverflow.com/questions/62020972/
how-can-i-apply-a-while-loop-to-this-text-based-adventure-game-where-the-prompt
https://www.youtube.com/watch?v=EbAdsK8s0-U
https://codereview.stackexchange.com/questions/93147/run-loop-for-a-text-
based-adventure-game/93153
https://letstalkdata.com/2014/08/how-to-write-a-text-adventure-in-python-
part-4-the-game-loop/
https://www.youtube.com/watch?v=DEcFCn2ubSg
https://www.youtube.com/watch?v=ypNFNr72Xe8
https://www.youtube.com/watch?v=HzDcKq2NDwM
https://www.youtube.com/watch?v=miuHrP2O7Jw

    
    There are bugs when the user doesn't follow the correct spelling and 
    capitalization or write in the exact phrase or number.
   
   Changes from origianl version:
    ( 'prompt = ' ) was implemented
    random package  random.randint was implemented
    deleted where else clause could not code
    inserting codes into functions
    added in working code
    changed stages

    
"""


#Define a introduction function 
def Introduction():
    """Introduction and restarting screen"""

#Prints the intro to the game
    print("""
You're wandering the Tokyo and about to embark on an adventure...
To make it through the game, you will go through 4 stages to eventually save 
the world or fail the world.
""")
#Define the journey
def adventure_awaits():
    print("User will start his/her/their journey.")

#Define the losing the game by the you_failed function
def you_failed():
    """ When a player fails the game, this should be the ending screen they 
    see with a game over message. Function should also allow the user to
    restart the game from the beginning."""
#Prints part of the story line
    print(f""" 
        No! The Dark Kingdown has won and everything you love is lost...unless...""")
    
def thanks_for_playing():
    print("Thanks for playing and saving the world, Guardian Warrior!")
                


from sys import exit
#Importing the random function
import random
#Importing the time function
import time

#Stage 1 prompting introduction of Luna your guide
#prompt and input

#Prompts for user input
adventure_awaits = input(prompt = "Press Enter to start your journey")

#calling the intoduction function
Introduction()

print(
    """Hello Tokyo citizen minding his/her/their own business! 
    What's your name? \n """)
user_name = input()
print("\n")
from time import sleep
time.sleep(1)

print(f""" {user_name.capitalize()}, a cat walks up to you; out of habit you say 
'Hi kitty, kitty!' but you didn't expect it to answer you!\n""")
time.sleep(1)
print(f"""     'Hi {user_name.capitalize()} , I am Luna, advisor to the 
    Queen of the Silver Millenium Moon Kingdom!'\n""")
print("You stare at Luna in disbelief.\n")
time.sleep(1)  
print("""'Yes, I am talking black cat, but you must get past that point. 
    Believe it or not, you are a reincarnate of a Warrior Guardian 
    from the famed Sailor Scouts.'\n""")
time.sleep(1)   
print(
    """'I know that is a lot to take in, but please take this magical pendant
    to transform into a warrior. All goodness in the Universe depense on it. 
    You will have to take accountability
    if you fail!' \n""")

#Player takes the pendant to play.
time.sleep(1)
take_pendant = input(prompt = """
Press Enter to accept this adventure and take the pendant!\n """)
print("\n")
time.sleep(1)


print (
        
    """'Woohoo! You are so selfless and you're going to be an awesome Hero!
    Now come with me to find the rest of the Sailor Scouts!'\n"""
    )
input('<Press any key to continue>\n')
    
        
#prompting user for input

print("How do you feel right now? (enter an adjective)\n")  
feel = input()
print(f"""{feel.capitalize()} is how Luna feels too!""")


def stage_1():
    #stage 2 Finding the Other Sailor Scouts
    print("Luna tells you to follow her, but she quickly disappears.\n")
    print("Do you go left or right?\n")
    time.sleep(1)
    direction = input ("Enter left or right.")
    #nested conditional
    while True:    
        if direction == "left" in direction or "left.lowercase" in direction:
            print("Oh no, there is a Youma monster. Run Away!")
            input('<Press any key to continue>\n')
            stage_2()
        elif direction == "right"in direction or "right.lowercase" in direction:
            print("Great! No Dark Kingdom Youma monsters! You're on the right path!")
            input('<Press any key to continue>\n')  
            stage_2()
        elif direction != "left" in direction or "right" in direction:
            print("That's not good. Write left or right!")
            input('<Write "left" or "right">\n') 
            stage_1()
        else:
            print("Invalid entry. Please try again.\n")
            input('<Write "left" or "right">\n')
            stage_1()
        

def stage_2():
    print("Luna reappears and tells you that she knows which Sailor Scout you are!")
    input('<Press any key to continue>\n')
    
    print("Press 1, 2, 3, or 4 to find who out who you truly are!")
    
    choice = input("> ")
    
    if choice == '1':
        print("Congratulations, you are Sailor Mercury and your element is Water!")
        input('<Press any key to continue>\n')
        stage_3()
    elif choice == '2':
        print("Congratulations, you are Sailor Mars and your element is Fire!")
        input('<Press any key to continue>\n')
        stage_3()
    elif choice == '3' in choice or "three" in choice:
        print("Congratulations, you are Sailor Venus and your element is Love!")
        input('<Press any key to continue>\n')
        stage_3()
    elif choice == '4' in choice or "four" in choice:
        print("Congratulations, you are Sailor Jupiter and your element is Thunder!")
        input('<Press any key to continue>\n')
        stage_3()
         
            
        # End of nested conditional
    elif choice == '5':
        print("Invalid entry. Please try again.\n")
        input('<Press any key to continue>\n')
        stage_1()
    
    else:
        print("Invalid entry. Please try again.\n")
        input('<Press any key to continue>\n')
        stage_1()
    
    input('<Press any key to continue>\n')
    stage_3()
    
    
def stage_3():
    print("Guardian Warrior, keep going! Go find the other Scouts!\n")
    input('<Press any key to continue>\n')
   
    print("""You see a light beam. With your magic pendant your transform 
    into a Guardian and run towards it.\n""")
    time.sleep(2)
    print("Press 1 to go into the beam to find the other Scouts.")
    print("Press 2 to cry and fail.")
    
    choice_s2 = input("> ")
    
    if choice_s2 == '1':
        stage_4()

    elif choice_s2 == '2':
        you_failed()
    
    else:
        print("Invalid entry. Please try again.\n")
        stage_2()
    time.sleep(1)
    
def stage_4():
    print("""Yay! The Sailor Scouts are together and you all know that it is 
            mission critical to find the Millenium Moon Princess!\n""")
    input('<Press any key to continue>\n')
    time.sleep(1)    
    print("\n")
    print("""With all the Scouts together, past memories return 
            and figure out that Sailor Moon is Princess Serentiy.\n""")
    time.sleep(1) 
    print("\n")
    print("You ask Princess Serenity if she has the Silver Crystal")
    time.sleep(1)
    print("\n")
    print(f"""Princess Serenity says, 'Yes {user_name.capitalize()}, it is here in my heart!''""")
    time.sleep(1)
    print("\n")
    print("All the Sailor Scouts rejoice and you say, 'Time to kick Dark Kingdom booty!'")
    time.sleep(1)
    print("\n")
    print("\n")
    print("""Type 1 to follow Sailor Moon to space to fight the 
            Yourma monsters and the Queens of the Dark Kingdom.""")
    print("Press 2 to run away and fail.")
    
    choice_s3 = input("> ")
    
    if choice_s3 == '1':
        stage_5()

    elif choice_s3 == '2':
        you_failed()
    
    else:
        print("Invalid entry. Please try again.\n")
        stage_2()


def stage_5():
    print("""
    You all enter the Dark Kingdom in Space and you all use your powers
    to evade attacks and maim the enemies.
    The fight is getting tough and you all feel about to give up! 
    But there is push in you still!
    Do you give strength to Princess Sernity and the Silver crystal 
    to defeat the monsters and the Queens of the Dark Kingodom!?\n""")
    
    
    
    #Prompt for user input choice to follow
    choice_s4 = input(prompt = """
    What will you do? Enter either 1, 2, or 3:
    1) You decide to pray for other heros to come save you all.
    2) You contine to fight the Dark Kingdom with Moon Beam Power
    3) You Run away
    
    """)    
    #Convert any string into lower case
    choice_s4 = choice_s4.lower()
 
 #Start an If statement
    if "1" in choice_s4 or "one" in choice_s4:
        print("You can pray, but you need to fight!") 
        input(prompt = "<Press Enter to go back>") 
        stage_4()

    elif "2" in choice_s4 or "two" in choice_s4:
    # declaring hits as random number of moon beams
        hits = random.randint(1,6) #moon beams between 1-6
            #nested conditional statement
        while True: # looping 
            # conditional statement
                if hits < 2: #moon beams below 2
                    print(f" {hits} Moon Beam is enouogh; the enemey is weaken!")
                    final_battle()
                elif hits >= 2 and hits < 5: 
                    print(f"Wow! {hits} Moon Beams destroys some of the monsters!")
                    final_battle()

                elif hits >= 5: 
                    print(f"{hits} Moon Beams destroys all but Queen Beryl")
                    final_battle()
                else: #prints error asking for an answer with a number
                    print(f"Enter a number.")
                    input('<Press any key to continue>\n')
              
    elif "3" in choice_s4 or "three" in choice_s4:
            print("You can't quit!")
            stage_5()
            
    def final_battle():    
        time.sleep(3)
        print(""" Now all you have to do to win is to push Enter, representing the
            full power of the Sailor Scouts behind Princess Serenity!\n""")
        input('<Press Enter>\n')
   

        print("Evil is Defeated, Congratulations Sailor Scouts, you saved the world!")
        print("Wait... is that dark comet coming down to the atmosphere?!")
        print("Looks like a job for the Sailor Scouts!")
        thanks_for_playing()



    

stage_1()
